# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
import urllib 

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
from datetime import datetime

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# # Starting URL for Weather Map API Call
# api_key = "db27cde648420e9ff856833c33567353"

# url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# print(url)

# %%
# # List of city data
# city_data = []

# %%
# Create an empty list to store the responses
city_data = []

# set up lists to hold reponse info
lat = []
lng = []
temp = []
cloud = []
humidity = []
country = []
date = []
wind = []
city_table = []

#URL and Units to use
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# Make a request for each of the indices
for x in range(len(cities)):
    print(f"Processing Record {x} for Set {cities[x]}")

    # Get one of the posts
    try:
        post_response = requests.get(query_url + str(cities[x])).json()
        city_table.append(post_response['name'])
        cloud.append(post_response['clouds']['all'])
        humidity.append(post_response['main']['humidity'])
        country.append(post_response['sys']['country'])
        lat.append(post_response['coord']['lat'])
        lng.append(post_response['coord']['lon'])
        temp.append(post_response['main']['temp_max'])
        wind.append(post_response['wind']['speed'])
        date.append(post_response['dt'])
    except KeyError:
        print("City not found. Skipping...")
       
    # Save post's JSON
    city_data.append(post_response)
# Out:
# Processing Record 0 for Set mangan
# Processing Record 1 for Set punta arenas
# Processing Record 2 for Set busselton
# Processing Record 3 for Set cockburn town
# Processing Record 4 for Set yellowknife
# Processing Record 5 for Set chokurdakh
# Processing Record 6 for Set xichang
# Processing Record 7 for Set bonthe
# Processing Record 8 for Set bredasdorp
# Processing Record 9 for Set rikitea
# Processing Record 10 for Set roald
# Processing Record 11 for Set puerto carreno
# Processing Record 12 for Set albany
# Processing Record 13 for Set kushiro
# Processing Record 14 for Set mehamn
# Processing Record 15 for Set ostrovnoy
# Processing Record 16 for Set tabou
# Processing Record 17 for Set khatanga
# Processing Record 18 for Set mount isa
# Processing Record 19 for Set teya
# Processing Record 20 for Set bethel
# Processing Record 21 for Set oranjemund
# Processing Record 22 for Set new norfolk
# Processing Record 23 for Set saint-philippe
# Processing Record 24 for Set puerto madryn
# Processing Record 25 for Set avarua
# Processing Record 26 for Set baiyin
# Processing Record 27 for Set port alfred
# Processing Record 28 for Set dordrecht
# Processing Record 29 for Set itamaraju
# Processing Record 30 for Set hithadhoo
# Processing Record 31 for Set puerto ayora
# Processing Record 32 for Set hobart
# Processing Record 33 for Set bluff
# Processing Record 34 for Set san patricio
# Processing Record 35 for Set qaanaaq
# Processing Record 36 for Set kaitangata
# Processing Record 37 for Set mys shmidta
# City not found. Skipping...
# Processing Record 38 for Set sretensk
# Processing Record 39 for Set ushuaia
# Processing Record 40 for Set fort nelson
# Processing Record 41 for Set kapaa
# Processing Record 42 for Set pisco
# Processing Record 43 for Set hilo
# Processing Record 44 for Set neiba
# Processing Record 45 for Set carnarvon
# Processing Record 46 for Set saint anthony
# Processing Record 47 for Set mataura
# Processing Record 48 for Set moroni
# Processing Record 49 for Set saldanha
# Processing Record 50 for Set araouane
# Processing Record 51 for Set van
# Processing Record 52 for Set progreso
# Processing Record 53 for Set havre-saint-pierre
# Processing Record 54 for Set jamestown
# Processing Record 55 for Set isla mujeres
# Processing Record 56 for Set hermanus
# Processing Record 57 for Set san quintin
# Processing Record 58 for Set mar del plata
# Processing Record 59 for Set wamba
# Processing Record 60 for Set egvekinot
# Processing Record 61 for Set vaini
# Processing Record 62 for Set vangaindrano
# Processing Record 63 for Set druzhba
# Processing Record 64 for Set hamilton
# Processing Record 65 for Set norman wells
# Processing Record 66 for Set myitkyina
# Processing Record 67 for Set margate
# Processing Record 68 for Set skegness
# Processing Record 69 for Set east london
# Processing Record 70 for Set butaritari
# Processing Record 71 for Set bambous virieux
# Processing Record 72 for Set ilulissat
# Processing Record 73 for Set lakatoro
# Processing Record 74 for Set luanda
# Processing Record 75 for Set high level
# Processing Record 76 for Set tasiilaq
# Processing Record 77 for Set kruisfontein
# Processing Record 78 for Set auki
# Processing Record 79 for Set manta
# Processing Record 80 for Set ryotsu
# Processing Record 81 for Set magistralnyy
# Processing Record 82 for Set amderma
# City not found. Skipping...
# Processing Record 83 for Set kakonko
# Processing Record 84 for Set awbari
# Processing Record 85 for Set adrar
# Processing Record 86 for Set upernavik
# Processing Record 87 for Set ponta do sol
# Processing Record 88 for Set atuona
# Processing Record 89 for Set codrington
# Processing Record 90 for Set georgetown
# Processing Record 91 for Set yatou
# Processing Record 92 for Set nikolskoye
# Processing Record 93 for Set leh
# Processing Record 94 for Set clyde river
# Processing Record 95 for Set castro
# Processing Record 96 for Set kardailovo
# Processing Record 97 for Set houma
# Processing Record 98 for Set cape town
# Processing Record 99 for Set yerbogachen
# Processing Record 100 for Set broome
# Processing Record 101 for Set ha tinh
# Processing Record 102 for Set ascension
# City not found. Skipping...
# Processing Record 103 for Set solnechnyy
# Processing Record 104 for Set zatoka
# Processing Record 105 for Set quata
# Processing Record 106 for Set ugoofaaru
# Processing Record 107 for Set kodiak
# Processing Record 108 for Set cherskiy
# Processing Record 109 for Set shelburne
# Processing Record 110 for Set tiksi
# Processing Record 111 for Set sept-iles
# Processing Record 112 for Set jaru
# Processing Record 113 for Set port elizabeth
# Processing Record 114 for Set bengkulu
# City not found. Skipping...
# Processing Record 115 for Set chimbote
# Processing Record 116 for Set umm lajj
# Processing Record 117 for Set saint george
# Processing Record 118 for Set talnakh
# Processing Record 119 for Set komsomolskiy
# Processing Record 120 for Set san vicente
# Processing Record 121 for Set flinders
# Processing Record 122 for Set whitehorse
# Processing Record 123 for Set sabla
# Processing Record 124 for Set rosetta
# Processing Record 125 for Set ksenyevka
# City not found. Skipping...
# Processing Record 126 for Set thompson
# Processing Record 127 for Set yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 128 for Set marzuq
# Processing Record 129 for Set constitucion
# Processing Record 130 for Set sentyabrskiy
# City not found. Skipping...
# Processing Record 131 for Set tsihombe
# City not found. Skipping...
# Processing Record 132 for Set sakaiminato
# Processing Record 133 for Set ancud
# Processing Record 134 for Set pevek
# Processing Record 135 for Set qinzhou
# Processing Record 136 for Set kamenskoye
# City not found. Skipping...
# Processing Record 137 for Set zhuhai
# Processing Record 138 for Set bonavista
# Processing Record 139 for Set sao joao do paraiso
# Processing Record 140 for Set haines junction
# Processing Record 141 for Set illoqqortoormiut
# City not found. Skipping...
# Processing Record 142 for Set barentsburg
# City not found. Skipping...
# Processing Record 143 for Set cajimos
# Processing Record 224 for Set colares
# Processing Record 225 for Set bamnet narong
# Processing Record 226 for Set diplo
# Processing Record 227 for Set attawapiskat
# City not found. Skipping...
# Processing Record 228 for Set caravelas
# Processing Record 229 for Set sakakah
# City not found. Skipping...
# Processing Record 230 for Set juneau
# Processing Record 231 for Set saint-augustin
# Processing Record 232 for Set harper
# Processing Record 233 for Set baykit
# Processing Record 234 for Set lagoa
# Processing Record 235 for Set balabac
# Processing Record 236 for Set ghugus
# Processing Record 237 for Set carutapera
# Processing Record 238 for Set boali
# Processing Record 239 for Set mizdah
# Processing Record 240 for Set naze
# Processing Record 241 for Set pathein
# Processing Record 242 for Set azrow
# City not found. Skipping...
# Processing Record 243 for Set pervomayskiy
# Processing Record 244 for Set dien bien
# City not found. Skipping...
# Processing Record 245 for Set loviisa
# Processing Record 246 for Set sungairaya
# Processing Record 247 for Set barbar
# City not found. Skipping...
# Processing Record 248 for Set soria
# Processing Record 249 for Set vanavara
# Processing Record 250 for Set azangaro
# Processing Record 251 for Set hervey bay
# Processing Record 252 for Set khash
# Processing Record 253 for Set galiwinku
# City not found. Skipping...
# Processing Record 254 for Set bilibino
# Processing Record 255 for Set klaksvik
# Processing Record 256 for Set qaqortoq
# Processing Record 257 for Set aripuana
# Processing Record 258 for Set yokadouma
# Processing Record 259 for Set khandbari
# Processing Record 260 for Set haicheng
# Processing Record 261 for Set mozarlandia
# Processing Record 262 for Set west wendover
# Processing Record 263 for Set gupitan
# Processing Record 264 for Set conakry
# Processing Record 265 for Set victoria
# Processing Record 266 for Set kopyevo
# City not found. Skipping...
# Processing Record 267 for Set kargasok
# Processing Record 268 for Set labuan
# Processing Record 269 for Set hobyo
# Processing Record 270 for Set salalah
# Processing Record 271 for Set coquimbo
# Processing Record 272 for Set ust-nera
# Processing Record 273 for Set lethem
# Processing Record 274 for Set dingle
# Processing Record 275 for Set turayf
# Processing Record 276 for Set kattivakkam
# Processing Record 277 for Set saint-pierre
# Processing Record 278 for Set nuevo progreso
# Processing Record 279 for Set koumac
# Processing Record 280 for Set nanortalik
# Processing Record 281 for Set parabel
# Processing Record 282 for Set narsaq
# Processing Record 283 for Set luau
# Processing Record 284 for Set northam
# Processing Record 285 for Set svetlaya
# Processing Record 286 for Set iquique
# Processing Record 287 for Set iquitos
# Processing Record 288 for Set umzimvubu
# City not found. Skipping...
# Processing Record 289 for Set kralendijk
# Processing Record 290 for Set sogdiondon
# City not found. Skipping...
# Processing Record 291 for Set almaty
# Processing Record 292 for Set conde
# Processing Record 293 for Set san cristobal
# Processing Record 294 for Set guerrero negro
# Processing Record 295 for Set durango
# Processing Record 296 for Set olsztyn
# Processing Record 297 for Set tessalit
# Processing Record 298 for Set pafos
# City not found. Skipping...
# Processing Record 299 for Set tautira
# Processing Record 300 for Set barcelos
# Processing Record 301 for Set luderitz
# Processing Record 302 for Set suntar
# Processing Record 303 for Set dwarka
# Processing Record 304 for Set ribeira grande
# Processing Record 305 for Set ishigaki
# Processing Record 306 for Set miyako
# Processing Record 307 for Set santa eulalia del rio
# Processing Record 391 for Set bathsheba
# Processing Record 392 for Set henties bay
# Processing Record 393 for Set fairbanks
# Processing Record 394 for Set ahipara
# Processing Record 395 for Set abu zabad
# Processing Record 396 for Set vardo
# Processing Record 397 for Set san andres
# Processing Record 398 for Set kudahuvadhoo
# Processing Record 399 for Set pimentel
# Processing Record 400 for Set isangel
# Processing Record 401 for Set parrita
# Processing Record 402 for Set rudnogorsk
# Processing Record 403 for Set chandur bazar
# Processing Record 404 for Set pochutla
# Processing Record 405 for Set necochea
# Processing Record 406 for Set cabo rojo
# Processing Record 407 for Set eureka
# Processing Record 408 for Set port moresby
# Processing Record 409 for Set olafsvik
# City not found. Skipping...
# Processing Record 410 for Set mormugao
# City not found. Skipping...
# Processing Record 411 for Set vila franca do campo
# Processing Record 412 for Set consett
# Processing Record 413 for Set bandarbeyla
# Processing Record 414 for Set korsakovo
# Processing Record 415 for Set yendi
# Processing Record 416 for Set mount gambier
# Processing Record 417 for Set whyalla
# Processing Record 418 for Set pacific grove
# Processing Record 419 for Set cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 420 for Set ostersund
# Processing Record 421 for Set bandundu
# Processing Record 422 for Set fortuna
# Processing Record 423 for Set tabory
# Processing Record 424 for Set marcona
# City not found. Skipping...
# Processing Record 425 for Set palana
# Processing Record 426 for Set samarai
# Processing Record 427 for Set luganville
# Processing Record 428 for Set mokrous
# Processing Record 429 for Set mulki
# Processing Record 430 for Set esil
# Processing Record 431 for Set nizhneyansk
# City not found. Skipping...
# Processing Record 432 for Set grindavik
# Processing Record 433 for Set maldonado
# Processing Record 434 for Set methoni
# Processing Record 435 for Set petropavlovsk-kamchatskiy
# Processing Record 436 for Set tambun
# Processing Record 437 for Set beringovskiy
# Processing Record 438 for Set det udom
# Processing Record 439 for Set vysokogornyy
# Processing Record 440 for Set key west
# Processing Record 441 for Set morondava
# Processing Record 442 for Set pueblo nuevo
# Processing Record 443 for Set hosanagara
# Processing Record 444 for Set youkounkoun
# Processing Record 445 for Set mao
# Processing Record 446 for Set verkhnyaya inta
# Processing Record 447 for Set lasa
# Processing Record 448 for Set yuryevets
# Processing Record 449 for Set bubaque
# Processing Record 450 for Set khurba
# Processing Record 451 for Set itigi
# Processing Record 452 for Set mirante do paranapanema
# Processing Record 453 for Set lazarev
# Processing Record 454 for Set atar
# Processing Record 455 for Set luwuk
# Processing Record 456 for Set takoradi
# Processing Record 457 for Set palmer
# Processing Record 458 for Set rorvik
# Processing Record 459 for Set arlit
# Processing Record 460 for Set farafangana
# Processing Record 461 for Set faya
# Processing Record 462 for Set dickinson
# Processing Record 463 for Set vila velha
# Processing Record 464 for Set san jeronimo
# Processing Record 465 for Set ternate
# Processing Record 466 for Set houston
# Processing Record 467 for Set mahajanga
# Processing Record 468 for Set kazanskaya
# Processing Record 469 for Set vila do maio
# Processing Record 470 for Set baruun-urt
# Processing Record 471 for Set mendi
# Processing Record 472 for Set sharjah
# Processing Record 473 for Set finnsnes
# Processing Record 474 for Set marsh harbour
# Processing Record 475 for Set virginia beach
# Processing Record 476 for Set padang
# Processing Record 477 for Set tumannyy
# City not found. Skipping...
# Processing Record 478 for Set eregli
# Processing Record 479 for Set boa vista
# Processing Record 480 for Set beeville
# Processing Record 481 for Set coari
# Processing Record 482 for Set marsa matruh
# Processing Record 483 for Set vigia del fuerte
# Processing Record 484 for Set umm ruwabah
# City not found. Skipping...
# Processing Record 485 for Set ihosy
# Processing Record 486 for Set aykhal
# Processing Record 487 for Set yar-sale
# Processing Record 488 for Set tazovskiy
# Processing Record 489 for Set balta
# Processing Record 490 for Set zlobin
# Processing Record 491 for Set shihezi
# Processing Record 492 for Set ponta delgada
# Processing Record 493 for Set omboue
# Processing Record 494 for Set byumba
# Processing Record 495 for Set torremolinos
# Processing Record 496 for Set amberley
# Processing Record 497 for Set prince rupert
# Processing Record 498 for Set nova londrina
# Processing Record 499 for Set saint-paul
# Processing Record 500 for Set jackson
# Processing Record 501 for Set esna
# Processing Record 502 for Set sitka
# Processing Record 503 for Set denpasar
# Processing Record 504 for Set dover
# Processing Record 505 for Set charleston
# Processing Record 506 for Set verbivka
# Processing Record 507 for Set emba
# Processing Record 508 for Set kursumlija
# Processing Record 509 for Set alice springs
# Processing Record 510 for Set turan
# Processing Record 511 for Set fonte boa
# Processing Record 512 for Set aklavik
# Processing Record 513 for Set hun
# Processing Record 514 for Set khanpur
# Processing Record 515 for Set rudbar
# City not found. Skipping...
# Processing Record 516 for Set nome
# Processing Record 517 for Set dera din panah
# City not found. Skipping...
# Processing Record 518 for Set mareeba
# Processing Record 519 for Set falmouth
# Processing Record 520 for Set cagliari
# Processing Record 521 for Set deputatskiy
# Processing Record 522 for Set xining
# Processing Record 523 for Set znamenskoye
# Processing Record 524 for Set den helder
# Processing Record 525 for Set arman
# Processing Record 526 for Set saskylakh
# Processing Record 527 for Set ulu-telyak
# Processing Record 528 for Set sukumo
# Processing Record 529 for Set ondjiva
# Processing Record 530 for Set byron bay
# Processing Record 531 for Set okhotsk
# Processing Record 532 for Set razdolinsk
# Processing Record 533 for Set yertsevo
# Processing Record 534 for Set redlands
# Processing Record 535 for Set lhokseumawe
# Processing Record 536 for Set coruripe
# Processing Record 537 for Set meulaboh
# Processing Record 538 for Set rio tuba
# Processing Record 539 for Set nkoteng
# Processing Record 540 for Set montepuez
# Processing Record 541 for Set lorengau
# Processing Record 542 for Set hualmay
# Processing Record 543 for Set sikeston
# Processing Record 544 for Set pokrovsk
# Processing Record 545 for Set moree
# Processing Record 546 for Set cockburn harbour
# City not found. Skipping...
# Processing Record 547 for Set sulangan
# Processing Record 548 for Set terrace bay
# Processing Record 549 for Set stornoway
# City not found. Skipping...
# Processing Record 550 for Set chapais
# Processing Record 551 for Set nouadhibou
# Processing Record 552 for Set mrirt
# City not found. Skipping...
# Processing Record 553 for Set tongren
# Processing Record 554 for Set pombia
# Processing Record 555 for Set falkenberg
# Processing Record 556 for Set quatre cocos
# Processing Record 557 for Set vestmanna
# Processing Record 558 for Set chara
# Processing Record 559 for Set sao joao da barra
# Processing Record 560 for Set inirida
# Processing Record 561 for Set stafford
# Processing Record 562 for Set muroto
# Processing Record 563 for Set muyezerskiy
# Processing Record 564 for Set afanasyevo
# City not found. Skipping...
# Processing Record 565 for Set kuche
# City not found. Skipping...
# Processing Record 566 for Set grand gaube
# Processing Record 567 for Set iskateley
# Processing Record 568 for Set basyanovskiy
# City not found. Skipping...
# Processing Record 569 for Set nykoping
# Processing Record 570 for Set owosso
# Processing Record 571 for Set gorom-gorom
# Processing Record 572 for Set poshekhonye
# Processing Record 573 for Set bur gabo
# City not found. Skipping...
# Processing Record 574 for Set tairua
# Processing Record 575 for Set dasoguz
# Processing Record 576 for Set payyannur
# Processing Record 577 for Set tezu
# Processing Record 578 for Set san juan bautista
# Processing Record 579 for Set neiafu
# Processing Record 580 for Set urumqi
# City not found. Skipping...
# Processing Record 581 for Set timizart
# Processing Record 582 for Set mikkeli
# Processing Record 583 for Set lompoc
# Processing Record 584 for Set abu kamal
# Processing Record 585 for Set sidney
# Processing Record 586 for Set stephenville
# Processing Record 587 for Set dalianwan
# Processing Record 588 for Set mastic beach
# Processing Record 589 for Set san rafael
# Processing Record 590 for Set nagato
# Processing Record 591 for Set yumen
# Processing Record 592 for Set vostok
# Processing Record 593 for Set prieska
# Processing Record 594 for Set korem
# Processing Record 595 for Set krasnaya yaruga
# Processing Record 596 for Set port macquarie
# Processing Record 597 for Set okha
# Processing Record 598 for Set halalo
# City not found. Skipping...
# Processing Record 599 for Set udachnyy
# Processing Record 600 for Set otjimbingwe
# Processing Record 601 for Set doha
# Processing Record 602 for Set impfondo
# Processing Record 603 for Set rome
# Processing Record 604 for Set alyangula
# Processing Record 605 for Set safwah
# City not found. Skipping...
# Processing Record 606 for Set kalabo
# Processing Record 607 for Set bukama
# Processing Record 608 for Set boguchany
# Processing Record 609 for Set noumea
# Processing Record 610 for Set panama city
# Processing Record 611 for Set voh
# Processing Record 612 for Set srandakan

# %%
print(len(city_table))
print(len(cloud))
print(len(country))
print(len(humidity))
print(len(lat))
print(len(lng))
print(len(temp))
print(len(wind))
print(len(date))
# Out:
# 549
# 549
# 549
# 549
# 549
# 549
# 549
# 549
# 549

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# # Export the City_Data into a csv
# city_data_pd.to_csv(output_data_file, index_label="City_ID")

# # Show Record Count
# city_data_pd.count()

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "City": city_table,
    "Cloudiness" : cloud,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Lat" : lat,
    "Lng" : lng, 
    "Max Temp": temp,
    "Wind Speed" : wind
}
city_data_pd = pd.DataFrame(weather_dict)
city_data_pd.head()

#np.savetxt("city_data.csv", city_data_pd, delimiter=",")
city_data_pd.to_csv("city_data.csv")

# %%
city_data_pd.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         Mangan          55      IN  1576095806        73  27.50   88.54
# 1   Punta Arenas          90      CL  1576095372        57 -53.16  -70.91
# 2      Busselton          23      AU  1576095371        37 -33.64  115.35
# 3  Cockburn Town           0      TC  1576095474        79  21.46  -71.14
# 4    Yellowknife          20      CA  1576095374        67  62.45 -114.38
#
#    Max Temp  Wind Speed
# 0     35.92        5.06
# 1     55.40       19.46
# 2     64.99       15.95
# 3     79.54       18.03
# 4    -27.40        3.36

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat, temp, marker="o")

# Incorporate the other graph properties
plt.title("City Latitude Vs Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TempVsLat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(lat, humidity, marker="o")

# Incorporate the other graph properties
plt.title("City Latitude Vs Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityVsLat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(lat, cloud, marker="o")

# Incorporate the other graph properties
plt.title("City Latitude Vs Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessVsLat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(lat, wind, marker="o")

# Incorporate the other graph properties
plt.title("City Latitude Vs Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindSpeedVsLat.png")

# Show plot
plt.show()
